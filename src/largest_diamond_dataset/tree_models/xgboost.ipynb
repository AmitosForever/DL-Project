# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import pickle
import json
from pathlib import Path
import os
from sklearn.model_selection import RandomizedSearchCV
import optuna

# %%
script_dir = os.getcwd()
data_dir = Path(script_dir).parent / "data"

# %%
# Load the preprocessed data
X_train = np.load(f'{data_dir}/X_train_final.npy')
X_val = np.load(f'{data_dir}/X_val_final.npy')
X_test = np.load(f'{data_dir}/X_test_final.npy')

y_train_log = np.load(f'{data_dir}/y_train_log.npy')  # Log-transformed version!
y_val_log = np.load(f'{data_dir}/y_val_log.npy')
y_test_log = np.load(f'{data_dir}/y_test_log.npy')

# %%
max(np.expm1(y_test_log))  # To get back to original scale
# Out:
# np.float64(66512.99999999997)

# %%
model = xgb.XGBRegressor(
    n_estimators=1000,           # Number of trees
    learning_rate=0.1,          # Step size shrinkage (eta)
    max_depth=7,                 # Maximum tree depth
    min_child_weight=5,          # Minimum sum of instance weight in a child
    subsample=0.8,               # Fraction of samples for each tree
    colsample_bytree=1.0,        # Fraction of features for each tree
    gamma=0.1,                     # Minimum loss reduction for split
    reg_alpha=0.1,               # L1 regularization
    reg_lambda=1.0,              # L2 regularization
    random_state=42,
    n_jobs=-1,  
    device='cuda',                # Use all CPU cores
    #early_stopping_rounds=50,    # Stop if no improvement for 50 rounds
    eval_metric='mphe'          # Evaluation metric
)

# %%
model.fit(
    X_train, y_train_log,
    eval_set=[(X_train, y_train_log), (X_val, y_val_log)],
    verbose=50  # Print every 50 iterations
)
# Out:
# [0]	validation_0-mphe:0.37157	validation_1-mphe:0.37175
# [50]	validation_0-mphe:0.01759	validation_1-mphe:0.01823
# [100]	validation_0-mphe:0.01424	validation_1-mphe:0.01507
# [150]	validation_0-mphe:0.01329	validation_1-mphe:0.01449
# [200]	validation_0-mphe:0.01267	validation_1-mphe:0.01436
# [250]	validation_0-mphe:0.01215	validation_1-mphe:0.01450
# [300]	validation_0-mphe:0.01187	validation_1-mphe:0.01460
# [350]	validation_0-mphe:0.01163	validation_1-mphe:0.01469
# [400]	validation_0-mphe:0.01147	validation_1-mphe:0.01476
# [450]	validation_0-mphe:0.01131	validation_1-mphe:0.01482
# [500]	validation_0-mphe:0.01118	validation_1-mphe:0.01492
# [550]	validation_0-mphe:0.01107	validation_1-mphe:0.01499
# [600]	validation_0-mphe:0.01099	validation_1-mphe:0.01503
# [650]	validation_0-mphe:0.01089	validation_1-mphe:0.01507
# [700]	validation_0-mphe:0.01082	validation_1-mphe:0.01512
# [750]	validation_0-mphe:0.01074	validation_1-mphe:0.01515
# [800]	validation_0-mphe:0.01067	validation_1-mphe:0.01522
# [850]	validation_0-mphe:0.01061	validation_1-mphe:0.01527
# [900]	validation_0-mphe:0.01055	validation_1-mphe:0.01529
# [950]	validation_0-mphe:0.01049	validation_1-mphe:0.01535
# [999]	validation_0-mphe:0.01043	validation_1-mphe:0.01537
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='mphe', feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=5, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_train_pred_log = model.predict(X_train)
y_val_pred_log = model.predict(X_val)
y_test_pred_log = model.predict(X_test)

# Convert back to original price scale
y_train_actual = np.expm1(y_train_log)
y_train_pred = np.expm1(y_train_pred_log)

y_val_actual = np.expm1(y_val_log)
y_val_pred = np.expm1(y_val_pred_log)

# %%
def calculate_metrics(y_true, y_pred, dataset_name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    print(f"\n{dataset_name} Metrics:")
    print(f"  RMSE: ${rmse:,.2f}")
    print(f"  MAE:  ${mae:,.2f}")
    print(f"  R²:   {r2:.4f}")
    print(f"  MAPE: {mape:.2f}%")
    
    return {'rmse': rmse, 'mae': mae, 'r2': r2, 'mape': mape}

train_metrics = calculate_metrics(y_train_actual, y_train_pred, "Training")
val_metrics = calculate_metrics(y_val_actual, y_val_pred, "Validation")
# Out:
# Training Metrics:
#   RMSE: $1,934.45
#   MAE:  $587.13
#   R²:   0.9464
#   MAPE: 9.66%
#
# Validation Metrics:
#   RMSE: $2,267.27
#   MAE:  $665.59
#   R²:   0.9258
#   MAPE: 11.23%

# %%
param_dist = {
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_weight': [1, 5, 10],
    'gamma': [0, 0.1, 0.5, 1],
    'n_estimators': [500, 1000]
}

# Initialize the model
xgb_model = xgb.XGBRegressor(random_state=42, n_jobs=-1)

# Set up the search
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist,
    n_iter=20,           # Number of combinations to try
    scoring='neg_mean_squared_error',
    cv=3,                # 3-fold cross-validation
    verbose=1,
    random_state=42
)

# Fit the search
random_search.fit(X_train, y_train_log)

print(f"Best Parameters: {random_search.best_params_}")
best_model = random_search.best_estimator_
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'subsample': 1.0, 'n_estimators': 1000, 'min_child_weight': 5, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0.1, 'colsample_bytree': 1.0}

# %%
def objective(trial):
    # 1. Define the Expanded Parameter Space
    param = {
        # GPU Acceleration
        'tree_method': 'hist',
        'device': 'cuda',  # Use 'gpu' if using an older version of XGBoost
        
        # Core Hyperparameters
        'n_estimators': 2000, # Set high, let early stopping handle the rest
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        
        # Regularization (To fix your overfitting)
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        
        # Sampling
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
        
        'random_state': 42,
        'early_stopping_rounds': 50
    }

    # 2. Initialize and Fit
    model = xgb.XGBRegressor(**param, eval_metric='mphe')
    
    # We use the log-transformed data directly for tuning speed
    model.fit(
        X_train, y_train_log,
        eval_set=[(X_val, y_val_log)],
        verbose=False
    )

    # 3. Evaluate on Validation Set
    preds = model.predict(X_val)
    preds = np.expm1(preds)  # Convert back to original scale
    y_val = np.expm1(y_val_log)
    rmse = np.sqrt(mean_squared_error(y_val, preds))
    
    return rmse

# 4. Create and Run the Study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100, show_progress_bar=True) # Start with 100 trials

print("\n--- Optimization Finished ---")
print(f"Best RMSE: {study.best_value:.4f}")
print(f"Best Params: {study.best_params}")
# Out:
# [I 2026-01-16 19:51:22,693] A new study created in memory with name: no-name-f093abd9-b1e3-4b7a-90c2-007c167d8cc1
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-16 19:51:28,028] Trial 0 finished with value: 2233.924251873164 and parameters: {'learning_rate': 0.015029602876362444, 'max_depth': 9, 'min_child_weight': 2, 'gamma': 3.9220358537999276e-07, 'reg_alpha': 8.009004288691503e-08, 'reg_lambda': 0.0011988746382583686, 'subsample': 0.5915533933723962, 'colsample_bytree': 0.502294383897068, 'colsample_bylevel': 0.7996105145036367}. Best is trial 0 with value: 2233.924251873164.
# [I 2026-01-16 19:51:30,049] Trial 1 finished with value: 2312.184580740944 and parameters: {'learning_rate': 0.018113995420535624, 'max_depth': 14, 'min_child_weight': 19, 'gamma': 0.9182979142632723, 'reg_alpha': 0.2165283746202694, 'reg_lambda': 5.761458269119316, 'subsample': 0.7741423270647365, 'colsample_bytree': 0.9437264507064214, 'colsample_bylevel': 0.5243007493225795}. Best is trial 0 with value: 2233.924251873164.
# [I 2026-01-16 19:51:31,336] Trial 2 finished with value: 2230.636841373205 and parameters: {'learning_rate': 0.06018222257517117, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 2.3392795639649724e-06, 'reg_alpha': 0.0025969235881006083, 'reg_lambda': 1.5476714222508945, 'subsample': 0.7429921796181547, 'colsample_bytree': 0.8522137236742133, 'colsample_bylevel': 0.9029973153569403}. Best is trial 2 with value: 2230.636841373205.
# [I 2026-01-16 19:51:34,401] Trial 3 finished with value: 2219.477059711673 and parameters: {'learning_rate': 0.01640130315706425, 'max_depth': 7, 'min_child_weight': 17, 'gamma': 1.1517774188768864e-05, 'reg_alpha': 0.15263045502778028, 'reg_lambda': 2.140093059765598e-06, 'subsample': 0.759791438047132, 'colsample_bytree': 0.8304114796386575, 'colsample_bylevel': 0.8192246098111455}. Best is trial 3 with value: 2219.477059711673.
# [I 2026-01-16 19:51:39,153] Trial 4 finished with value: 2218.7083150957938 and parameters: {'learning_rate': 0.016077740555324765, 'max_depth': 12, 'min_child_weight': 13, 'gamma': 0.03598961552438718, 'reg_alpha': 3.248503559955839, 'reg_lambda': 1.1605642044454947, 'subsample': 0.8061786372296202, 'colsample_bytree': 0.5915639515294415, 'colsample_bylevel': 0.8773752492630327}. Best is trial 4 with value: 2218.7083150957938.
# [I 2026-01-16 19:51:40,502] Trial 5 finished with value: 2278.16853834503 and parameters: {'learning_rate': 0.04039767905760198, 'max_depth': 6, 'min_child_weight': 6, 'gamma': 0.48428505319191256, 'reg_alpha': 0.014791142318199384, 'reg_lambda': 1.8435013348863386e-07, 'subsample': 0.9077504805987617, 'colsample_bytree': 0.7593835234086783, 'colsample_bylevel': 0.6151110722576443}. Best is trial 4 with value: 2218.7083150957938.
# [I 2026-01-16 19:51:41,151] Trial 6 finished with value: 2208.0408022403863 and parameters: {'learning_rate': 0.13356124024933883, 'max_depth': 8, 'min_child_weight': 20, 'gamma': 4.3960298443976894e-05, 'reg_alpha': 0.5377063273670922, 'reg_lambda': 0.002582536353129459, 'subsample': 0.7670595821061876, 'colsample_bytree': 0.7503795210715685, 'colsample_bylevel': 0.5461853980693513}. Best is trial 6 with value: 2208.0408022403863.
# [I 2026-01-16 19:51:42,829] Trial 7 finished with value: 2219.08369306964 and parameters: {'learning_rate': 0.035485774088810214, 'max_depth': 8, 'min_child_weight': 8, 'gamma': 0.02764240314357477, 'reg_alpha': 4.6872923791672936e-08, 'reg_lambda': 6.07901947431525e-08, 'subsample': 0.5581281346906638, 'colsample_bytree': 0.7095603927885176, 'colsample_bylevel': 0.6599457576167251}. Best is trial 6 with value: 2208.0408022403863.
# [I 2026-01-16 19
. Best is trial 14 with value: 2198.5859476017454.
# [I 2026-01-16 19:52:25,311] Trial 24 finished with value: 2211.5563317852334 and parameters: {'learning_rate': 0.04468177842056466, 'max_depth': 6, 'min_child_weight': 9, 'gamma': 0.050894732236982765, 'reg_alpha': 5.745108529249293e-05, 'reg_lambda': 0.04538134910583103, 'subsample': 0.9052667219984767, 'colsample_bytree': 0.6371697952052394, 'colsample_bylevel': 0.7317284964379993}. Best is trial 14 with value: 2198.5859476017454.
# [I 2026-01-16 19:52:28,463] Trial 25 finished with value: 2195.724960285614 and parameters: {'learning_rate': 0.027027452938174122, 'max_depth': 7, 'min_child_weight': 13, 'gamma': 0.0008192274385146544, 'reg_alpha': 0.0009624695510294867, 'reg_lambda': 0.0009968532763886095, 'subsample': 0.9585589829636172, 'colsample_bytree': 0.5706730508009457, 'colsample_bylevel': 0.5586123985067183}. Best is trial 25 with value: 2195.724960285614.
# [I 2026-01-16 19:52:31,377] Trial 26 finished with value: 2200.351836330159 and parameters: {'learning_rate': 0.03067033058326983, 'max_depth': 9, 'min_child_weight': 13, 'gamma': 1.0044584333922458e-07, 'reg_alpha': 0.023406684472607166, 'reg_lambda': 4.24650070578921e-06, 'subsample': 0.9627292012343197, 'colsample_bytree': 0.5876493836840537, 'colsample_bylevel': 0.5766407901714795}. Best is trial 25 with value: 2195.724960285614.
# [I 2026-01-16 19:52:34,653] Trial 27 finished with value: 2196.048976348772 and parameters: {'learning_rate': 0.030691611128698143, 'max_depth': 11, 'min_child_weight': 13, 'gamma': 1.0565111784554963e-07, 'reg_alpha': 0.03045162181433561, 'reg_lambda': 7.721341287899462e-06, 'subsample': 0.959207720192387, 'colsample_bytree': 0.6509476196750812, 'colsample_bylevel': 0.6430598576007114}. Best is trial 25 with value: 2195.724960285614.
# [I 2026-01-16 19:52:39,412] Trial 28 finished with value: 2191.2629844926737 and parameters: {'learning_rate': 0.021745452987449208, 'max_depth': 11, 'min_child_weight': 9, 'gamma': 1.0461765512023405e-07, 'reg_alpha': 0.0011163166539099561, 'reg_lambda': 3.248479677906873e-06, 'subsample': 0.9922170954749863, 'colsample_bytree': 0.6561329124241768, 'colsample_bylevel': 0.6464682834304968}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:52:43,036] Trial 29 finished with value: 2207.781140279927 and parameters: {'learning_rate': 0.023008660960976528, 'max_depth': 11, 'min_child_weight': 7, 'gamma': 2.005592899576692e-06, 'reg_alpha': 0.001345801776531617, 'reg_lambda': 1.8039370034427728e-06, 'subsample': 0.8861002791298823, 'colsample_bytree': 0.7146771361801962, 'colsample_bylevel': 0.7835131180012901}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:53:02,438] Trial 30 finished with value: 2284.694083285508 and parameters: {'learning_rate': 0.009123544656403896, 'max_depth': 15, 'min_child_weight': 1, 'gamma': 1.3748697598861727e-05, 'reg_alpha': 0.051493308829036064, 'reg_lambda': 5.634806025215946e-07, 'subsample': 0.9525253260384922, 'colsample_bytree': 0.6521353400579144, 'colsample_bylevel': 0.6307014516688518}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:53:07,640] Trial 31 finished with value: 2205.7712957301833 and parameters: {'learning_rate': 0.02414464852487628, 'max_depth': 11, 'min_child_weight': 9, 'gamma': 1.499683645388426e-07, 'reg_alpha': 0.006399255581961107, 'reg_lambda': 0.0010384604874225615, 'subsample': 0.994554290836949, 'colsample_bytree': 0.522072819061914, 'colsample_bylevel': 0.7043525982746933}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:53:17,500] Trial 32 finished with value: 2211.6552574809803 and parameters: {'learning_rate': 0.011631729063472427, 'max_depth': 13, 'min_child_weight': 12, 'gamma': 6.767444901400994e-08, 'reg_alpha': 0.0007441275582355577, 'reg_lambda': 8.76236365324959e-06, 'subsample': 0.9633344304172922, 'colsample_bytree': 0.6357373866683643, 'colsample_bylevel': 0.653987114334841}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:53
. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:53:59,635] Trial 41 finished with value: 2198.999702342945 and parameters: {'learning_rate': 0.027070055755118012, 'max_depth': 9, 'min_child_weight': 15, 'gamma': 4.0754744301743346e-08, 'reg_alpha': 0.059569608455280046, 'reg_lambda': 1.194804834546884e-08, 'subsample': 0.9274090092431496, 'colsample_bytree': 0.7313951664329618, 'colsample_bylevel': 0.6375812043879083}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:01,565] Trial 42 finished with value: 2197.3327232623124 and parameters: {'learning_rate': 0.0463352319310054, 'max_depth': 9, 'min_child_weight': 16, 'gamma': 1.8215224454101896e-07, 'reg_alpha': 0.045220514501915145, 'reg_lambda': 5.202543258827508e-08, 'subsample': 0.9684836942204306, 'colsample_bytree': 0.6590862100080365, 'colsample_bylevel': 0.5833053180520609}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:03,983] Trial 43 finished with value: 2205.010757945164 and parameters: {'learning_rate': 0.043780305928816536, 'max_depth': 11, 'min_child_weight': 16, 'gamma': 2.1722047140202557e-08, 'reg_alpha': 0.006779615978598742, 'reg_lambda': 2.719393198563954e-07, 'subsample': 0.9690660014501438, 'colsample_bytree': 0.6562904303728864, 'colsample_bylevel': 0.5390754113567513}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:06,329] Trial 44 finished with value: 2208.7006218082984 and parameters: {'learning_rate': 0.05062536200447377, 'max_depth': 12, 'min_child_weight': 18, 'gamma': 1.0814437506759068e-07, 'reg_alpha': 0.02982813559244386, 'reg_lambda': 8.675199369024372e-08, 'subsample': 0.729531239919425, 'colsample_bytree': 0.6024292446200405, 'colsample_bylevel': 0.5774085127636474}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:08,690] Trial 45 finished with value: 2220.5717267875307 and parameters: {'learning_rate': 0.03367434408417517, 'max_depth': 9, 'min_child_weight': 13, 'gamma': 0.015132893088370484, 'reg_alpha': 9.148233878992972, 'reg_lambda': 1.5857112669909137e-06, 'subsample': 0.9724144330718247, 'colsample_bytree': 0.6879832014038262, 'colsample_bylevel': 0.6197871842066244}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:11,171] Trial 46 finished with value: 2205.312896023855 and parameters: {'learning_rate': 0.03711443238927364, 'max_depth': 6, 'min_child_weight': 10, 'gamma': 0.00014733554513598584, 'reg_alpha': 0.1561563583913264, 'reg_lambda': 4.805090316075306e-08, 'subsample': 0.9158324064948997, 'colsample_bytree': 0.6352739757553338, 'colsample_bylevel': 0.5835317170061423}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:20,068] Trial 47 finished with value: 2195.4541803851475 and parameters: {'learning_rate': 0.0134201730022679, 'max_depth': 14, 'min_child_weight': 14, 'gamma': 2.3591157262156806e-07, 'reg_alpha': 0.008077648408354003, 'reg_lambda': 0.0007955879820991875, 'subsample': 0.9993052109079724, 'colsample_bytree': 0.7672076139861651, 'colsample_bylevel': 0.5293253472326386}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:29,428] Trial 48 finished with value: 2201.2188841818806 and parameters: {'learning_rate': 0.01368399769175106, 'max_depth': 15, 'min_child_weight': 16, 'gamma': 6.190358997805246e-07, 'reg_alpha': 0.0032320222201307988, 'reg_lambda': 2.6313227925823567e-05, 'subsample': 0.9453922428717533, 'colsample_bytree': 0.7669446265360572, 'colsample_bylevel': 0.5295419595907834}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:39,290] Trial 49 finished with value: 2192.2593625182835 and parameters: {'learning_rate': 0.011068223478946688, 'max_depth': 14, 'min_child_weight': 20, 'gamma': 1.250575393372336e-08, 'reg_alpha': 0.011626170359699695, 'reg_lambda': 0.0014351056599243238, 'subsample': 0.9739976885287676, 'colsample_bytree': 0.7941861161755278, 'colsample_bylevel': 0.6197141118873165}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:46,963] Trial 50 finished with value: 2203.601656984146 and parameters: {'learning_rate': 0.011184984623682163, 'max_depth': 14, 'min_child_weight': 20, 'gamma': 1.616205695582038e-08, 'reg_alpha': 0.010787285426917126, 'reg_lambda': 0.0005044070419466619, 'subsample': 0.5995126367945105, 'colsample_bytree': 0.8461774629506598, 'colsample_bylevel': 0.6907829994296637}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:52,257] Trial 51 finished with value: 2200.9731105250294 and parameters: {'learning_rate': 0.020917290379020678, 'max_depth': 14, 'min_child_weight': 19, 'gamma': 4.812447899389442e-08, 'reg_alpha': 0.0006867926391660432, 'reg_lambda': 0.00334462542760942, 'subsample': 0.9793761297079605, 'colsample_bytree': 0.7934461891784652, 'colsample_bylevel': 0.5544998178903741}. Best is trial 28 with value: 2191.2629844926737.
# [I 2026-01-16 19:54:58,840] Trial 52 finished with value: 2189.4955436455225 and parameters: {'learning_rate': 0.01450028044288516, 'max_depth': 14, 'min_child_weight': 14, 'gamma': 1.9766679831681936e-07, 'reg_alpha': 0.0018198884824782875, 'reg_lambda': 7.217774845660382e-05, 'subsample': 0.9604144092351541, 'colsample_bytree': 0.9046189573755721, 'colsample_bylevel': 0.6107605025348347}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:55:04,805] Trial 53 finished with value: 2195.800224541743 and parameters: {'learning_rate': 0.01639137884349926, 'max_depth': 14, 'min_child_weight': 14, 'gamma': 1.0287325199280077e-08, 'reg_alpha': 0.0014734394538571834, 'reg_lambda': 0.00011710396402026408, 'subsample': 0.9243702643781266, 'colsample_bytree': 0.8875737808089653, 'colsample_bylevel': 0.6230177181801443}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:55:10,970] Trial 54 finished with value: 2197.196243138076 and parameters: {'learning_rate': 0.015545726363810382, 'max_depth': 14, 'min_child_weight': 14, 'gamma': 2.227752450216831e-08, 'reg_alpha': 0.0016439086770559498, 'reg_lambda': 0.001025007323638243, 'subsample': 0.9283867090850659, 'colsample_bytree': 0.9002185054960248, 'colsample_bylevel': 0.606054426717657}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:55:19,628] Trial 55 finished with value: 2198.4220800217618 and parameters: {'learning_rate': 0.008832876237676394, 'max_depth': 13, 'min_child_weight': 18, 'gamma': 1.1703312098338357e-08, 'reg_alpha': 0.00030835245115414444, 'reg_lambda': 0.00012945820245228038, 'subsample': 0.8967058144514618, 'colsample_bytree': 0.9132248023262415, 'colsample_bylevel': 0.6196633816807718}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:55:28,550] Trial 56 finished with value: 2192.3634421397314 and parameters: {'learning_rate': 0.01182846182244313, 'max_depth': 15, 'min_child_weight': 12, 'gamma': 5.969576334569254e-08, 'reg_alpha': 0.0031682711895253185, 'reg_lambda': 4.357143839608604e-05, 'subsample': 0.9838660322885224, 'colsample_bytree': 0.9357707315280371, 'colsample_bylevel': 0.525386854876568}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19
. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:57:27,324] Trial 66 finished with value: 2193.430982232785 and parameters: {'learning_rate': 0.01007715184503349, 'max_depth': 13, 'min_child_weight': 10, 'gamma': 1.5938660210552418e-06, 'reg_alpha': 0.10384328248844925, 'reg_lambda': 1.2068073971610508e-05, 'subsample': 0.9538535162781311, 'colsample_bytree': 0.9354381043171912, 'colsample_bylevel': 0.9541839280403144}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:57:34,084] Trial 67 finished with value: 2197.7944039589424 and parameters: {'learning_rate': 0.010037426702877748, 'max_depth': 13, 'min_child_weight': 10, 'gamma': 1.3148231671107447e-06, 'reg_alpha': 0.2704609391119222, 'reg_lambda': 8.358889927186238e-07, 'subsample': 0.8733573185293814, 'colsample_bytree': 0.9350395460905495, 'colsample_bylevel': 0.9984222695135839}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:57:41,486] Trial 68 finished with value: 2200.1315974396894 and parameters: {'learning_rate': 0.009985278024617714, 'max_depth': 12, 'min_child_weight': 6, 'gamma': 6.03745177325582e-07, 'reg_alpha': 0.10399079053052421, 'reg_lambda': 4.8939736208568285e-06, 'subsample': 0.952913790064568, 'colsample_bytree': 0.8658194052021521, 'colsample_bylevel': 0.7248067634084088}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:57:46,061] Trial 69 finished with value: 2231.936862948372 and parameters: {'learning_rate': 0.008156024193516163, 'max_depth': 13, 'min_child_weight': 8, 'gamma': 0.3960518212056771, 'reg_alpha': 0.00014193155815094515, 'reg_lambda': 1.5099165501776279e-05, 'subsample': 0.6769520340964184, 'colsample_bytree': 0.951015951431621, 'colsample_bylevel': 0.8663584909728694}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:57:53,237] Trial 70 finished with value: 2197.1354453621357 and parameters: {'learning_rate': 0.012285091846707112, 'max_depth': 13, 'min_child_weight': 10, 'gamma': 4.0580900235599615e-05, 'reg_alpha': 0.020382791814098355, 'reg_lambda': 6.712149646335595e-06, 'subsample': 0.9547937154807267, 'colsample_bytree': 0.8297745850617121, 'colsample_bylevel': 0.8876983957751323}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:01,838] Trial 71 finished with value: 2193.8589053182973 and parameters: {'learning_rate': 0.010082195368052056, 'max_depth': 14, 'min_child_weight': 11, 'gamma': 0.0007306129650773919, 'reg_alpha': 0.011294822767731314, 'reg_lambda': 4.7324364131040014e-05, 'subsample': 0.9833932222256502, 'colsample_bytree': 0.9700583993454572, 'colsample_bylevel': 0.5553474077459134}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:13,673] Trial 72 finished with value: 2194.7579431388162 and parameters: {'learning_rate': 0.00802917212167048, 'max_depth': 14, 'min_child_weight': 11, 'gamma': 1.0415747942528602e-07, 'reg_alpha': 0.00533424812883692, 'reg_lambda': 2.3189817960945464e-06, 'subsample': 0.9626407090443013, 'colsample_bytree': 0.9373141604271493, 'colsample_bylevel': 0.9809718225010117}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:20,280] Trial 73 finished with value: 2195.266458860791 and parameters: {'learning_rate': 0.01246685705550265, 'max_depth': 15, 'min_child_weight': 9, 'gamma': 1.4532366391138708e-07, 'reg_alpha': 0.49774140447916404, 'reg_lambda': 0.0005518322389872047, 'subsample': 0.9412620729965137, 'colsample_bytree': 0.9964744044931305, 'colsample_bylevel': 0.5925224800828853}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:27,622] Trial 74 finished with value: 2206.8813620736787 and parameters: {'learning_rate': 0.014228036809086516, 'max_depth': 14, 'min_child_weight': 7, 'gamma': 2.4653749020823887e-06, 'reg_alpha': 0.02815910342137915, 'reg_lambda': 2.4825298892401484e-05, 'subsample': 0.9999649146745226, 'colsample_bytree': 0.9149935182694091, 'colsample_bylevel': 0.9313474425534565}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:42,560] Trial 75 finished with value: 2197.7809298217526 and parameters: {'learning_rate': 0.0064712416422109354, 'max_depth': 15, 'min_child_weight': 10, 'gamma': 4.24124468883942e-07, 'reg_alpha': 0.1237204735813087, 'reg_lambda': 1.472942901714221e-05, 'subsample': 0.9795108294887064, 'colsample_bytree': 0.8926934379208215, 'colsample_bylevel': 0.8462360284957666}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:58:47,324] Trial 76 finished with value: 2195.268485502039 and parameters: {'learning_rate': 0.017863332823661746, 'max_depth': 14, 'min_child_weight': 11, 'gamma': 1.9160578404955857e-08, 'reg_alpha': 0.053070574780003654, 'reg_lambda': 1.1551510162680257e-06, 'subsample': 0.9150248702413818, 'colsample_bytree': 0.9443074055162886, 'colsample_bylevel': 0.7595662548199706}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:01,368] Trial 77 finished with value: 2190.8963689997267 and parameters: {'learning_rate': 0.005604334100687748, 'max_depth': 13, 'min_child_weight': 12, 'gamma': 0.00035385271483483216, 'reg_alpha': 0.0011470381349994484, 'reg_lambda': 7.326873997420813e-05, 'subsample': 0.9680355064358658, 'colsample_bytree': 0.9201404501571604, 'colsample_bylevel': 0.6550019047459651}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:09,398] Trial 78 finished with value: 2190.8769858224796 and parameters: {'learning_rate': 0.009331397009476577, 'max_depth': 12, 'min_child_weight': 10, 'gamma': 0.00040830667312657856, 'reg_alpha': 0.0009311057085215932, 'reg_lambda': 0.0001833503889052606, 'subsample': 0.9641816350566639, 'colsample_bytree': 0.9188946381030233, 'colsample_bylevel': 0.6641246686993998}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:21,335] Trial 79 finished with value: 2203.4551200461274 and parameters: {'learning_rate': 0.005651848239404189, 'max_depth': 12, 'min_child_weight': 13, 'gamma': 0.0004252068827247261, 'reg_alpha': 0.0009456870234150608, 'reg_lambda': 0.00667080779260607, 'subsample': 0.7798409840213929, 'colsample_bytree': 0.8699742261534492, 'colsample_bylevel': 0.6594639226387157}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:34,050] Trial 80 finished with value: 2205.2933223618393 and parameters: {'learning_rate': 0.006077715810377285, 'max_depth': 13, 'min_child_weight': 8, 'gamma': 0.0009936731811513325, 'reg_alpha': 0.00042319011127828573, 'reg_lambda': 0.0018183133568176887, 'subsample': 0.8215422851921979, 'colsample_bytree': 0.9069435508304302, 'colsample_bylevel': 0.6736991977035428}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:49,632] Trial 81 finished with value: 2195.798736016482 and parameters: {'learning_rate': 0.0050156017031208165, 'max_depth': 13, 'min_child_weight': 9, 'gamma': 0.00020217725097915543, 'reg_alpha': 0.0020443688756508396, 'reg_lambda': 0.0003390532003154158, 'subsample': 0.9635338337865527, 'colsample_bytree': 0.9252222892938897, 'colsample_bylevel': 0.6920770885816311}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 19:59:56,444] Trial 82 finished with value: 2214.1569644404103 and parameters: {'learning_rate': 0.00894884333616751, 'max_depth': 12, 'min_child_weight': 10, 'gamma': 0.0016234872442882997, 'reg_alpha': 8.519165912621627e-05, 'reg_lambda': 8.190548244415991e-05, 'subsample': 0.5045326441388277, 'colsample_bytree': 0.9266928064631815, 'colsample_bylevel': 0.6555610498254942}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:03,721] Trial 83 finished with value: 2190.106145449392 and parameters: {'learning_rate': 0.010740270393955049, 'max_depth': 13, 'min_child_weight': 11, 'gamma': 0.0004264256742020274, 'reg_alpha': 3.3615468052768034e-05, 'reg_lambda': 0.00020490649727488978, 'subsample': 0.9377838069652239, 'colsample_bytree': 0.9659829690526868, 'colsample_bylevel': 0.6432054560917212}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:08,997] Trial 84 finished with value: 2194.053790219177 and parameters: {'learning_rate': 0.012305737135327576, 'max_depth': 12, 'min_child_weight': 11, 'gamma': 0.006987953287806142, 'reg_alpha': 1.7769237773289697e-05, 'reg_lambda': 0.00014011182220635639, 'subsample': 0.932976148477163, 'colsample_bytree': 0.9608704957791648, 'colsample_bylevel': 0.6284446188652268}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:21,306] Trial 85 finished with value: 2227.932696071748 and parameters: {'learning_rate': 0.010967211486980993, 'max_depth': 14, 'min_child_weight': 3, 'gamma': 8.01416148167912e-05, 'reg_alpha': 3.241568323939537e-05, 'reg_lambda': 0.0005922287546536529, 'subsample': 0.9904032055720574, 'colsample_bytree': 0.8405432383210514, 'colsample_bylevel': 0.6099344989703684}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:27,455] Trial 86 finished with value: 2193.4672286265863 and parameters: {'learning_rate': 0.009560464822679603, 'max_depth': 10, 'min_child_weight': 12, 'gamma': 2.3664854386877747e-05, 'reg_alpha': 4.4560565023671375e-06, 'reg_lambda': 0.0018037339754568048, 'subsample': 0.9688634525201745, 'colsample_bytree': 0.8796933191046301, 'colsample_bylevel': 0.6676723276474021}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:32,629] Trial 87 finished with value: 2191.10692615752 and parameters: {'learning_rate': 0.015313353513588573, 'max_depth': 13, 'min_child_weight': 13, 'gamma': 0.00045547396532369226, 'reg_alpha': 0.0009711313761079836, 'reg_lambda': 0.00019746061250065067, 'subsample': 0.9210387464244121, 'colsample_bytree': 0.9721895104272025, 'colsample_bylevel': 0.6475393043638723}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:36,314] Trial 88 finished with value: 2200.4194585226132 and parameters: {'learning_rate': 0.015440135287771339, 'max_depth': 11, 'min_child_weight': 15, 'gamma': 0.00035163422953721197, 'reg_alpha': 0.00024364300888585582, 'reg_lambda': 0.00018227035335176652, 'subsample': 0.9216915795393984, 'colsample_bytree': 0.972569114558596, 'colsample_bylevel': 0.6470654039904851}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:40,050] Trial 89 finished with value: 2190.258742274546 and parameters: {'learning_rate': 0.018570635817991267, 'max_depth': 12, 'min_child_weight': 13, 'gamma': 0.0011362746619851534, 'reg_alpha': 0.0009357261703511007, 'reg_lambda': 6.726671797211346e-05, 'subsample': 0.9401758212567948, 'colsample_bytree': 0.949964626680021, 'colsample_bylevel': 0.7091944104980831}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:43,095] Trial 90 finished with value: 2195.8057098529653 and parameters: {'learning_rate': 0.022136444172167535, 'max_depth': 12, 'min_child_weight': 13, 'gamma': 0.0015003750460073802, 'reg_alpha': 0.0010796495154408185, 'reg_lambda': 0.000367664019260192, 'subsample': 0.8940736355379594, 'colsample_bytree': 0.9487600055458206, 'colsample_bylevel': 0.7169438982436324}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:47,090] Trial 91 finished with value: 2196.003671938967 and parameters: {'learning_rate': 0.018498683253502197, 'max_depth': 13, 'min_child_weight': 13, 'gamma': 0.00024209535817780006, 'reg_alpha': 0.0005544958872071259, 'reg_lambda': 6.989999324822716e-05, 'subsample': 0.9419408138684708, 'colsample_bytree': 0.9895112803239254, 'colsample_bylevel': 0.637886703412071}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:51,689] Trial 92 finished with value: 2192.3992038408924 and parameters: {'learning_rate': 0.014759852112550518, 'max_depth': 12, 'min_child_weight': 12, 'gamma': 0.0004725832119193083, 'reg_alpha': 0.004448018909938475, 'reg_lambda': 3.420499082814206e-05, 'subsample': 0.9722064601709893, 'colsample_bytree': 0.9689406165325161, 'colsample_bylevel': 0.6868503507834175}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:00:57,285] Trial 93 finished with value: 2192.6709107009083 and parameters: {'learning_rate': 0.012932872448993374, 'max_depth': 12, 'min_child_weight': 14, 'gamma': 0.00011037118192986666, 'reg_alpha': 0.0023020535913911956, 'reg_lambda': 0.0035465937247379548, 'subsample': 0.9564997071499841, 'colsample_bytree': 0.9155178466440989, 'colsample_bylevel': 0.7059634038841743}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:01,657] Trial 94 finished with value: 2195.3137428996697 and parameters: {'learning_rate': 0.01728801748518194, 'max_depth': 13, 'min_child_weight': 13, 'gamma': 0.005122520573119697, 'reg_alpha': 0.0001245277241970722, 'reg_lambda': 7.243605800724844e-05, 'subsample': 0.9051974858751929, 'colsample_bytree': 0.9469470133675718, 'colsample_bylevel': 0.7416467207519049}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:07,360] Trial 95 finished with value: 2192.783332048446 and parameters: {'learning_rate': 0.011633030471856598, 'max_depth': 11, 'min_child_weight': 12, 'gamma': 0.0009403866613924878, 'reg_alpha': 0.00023901715821027673, 'reg_lambda': 0.0002313441230757617, 'subsample': 0.9364730078932337, 'colsample_bytree': 0.8971065029514133, 'colsample_bylevel': 0.6663845177483237}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:11,131] Trial 96 finished with value: 2194.719299161483 and parameters: {'learning_rate': 0.02528978148753865, 'max_depth': 13, 'min_child_weight': 14, 'gamma': 0.0005888152003687664, 'reg_alpha': 0.0012352738252437428, 'reg_lambda': 0.0007720591624825987, 'subsample': 0.9700253567076966, 'colsample_bytree': 0.8177705834837307, 'colsample_bylevel': 0.6809500365446182}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:19,169] Trial 97 finished with value: 2197.883958781077 and parameters: {'learning_rate': 0.016357397471407364, 'max_depth': 14, 'min_child_weight': 15, 'gamma': 0.00027692710511589667, 'reg_alpha': 0.0007663538115565026, 'reg_lambda': 0.00014415705354858756, 'subsample': 0.9912825251916891, 'colsample_bytree': 0.749330598444155, 'colsample_bylevel': 0.6509003100548905}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:23,274] Trial 98 finished with value: 2200.6215189589993 and parameters: {'learning_rate': 0.01892096242120423, 'max_depth': 13, 'min_child_weight': 11, 'gamma': 5.587210553000372e-05, 'reg_alpha': 0.00041917854538419026, 'reg_lambda': 0.00042416560702600406, 'subsample': 0.8505278333105026, 'colsample_bytree': 0.961689223348876, 'colsample_bylevel': 0.595241255672554}. Best is trial 52 with value: 2189.4955436455225.
# [I 2026-01-16 20:01:27,715] Trial 99 finished with value: 2196.6322872473934 and parameters: {'learning_rate': 0.014657636450881322, 'max_depth': 12, 'min_child_weight': 12, 'gamma': 0.002379963087335787, 'reg_alpha': 0.004076503361725217, 'reg_lambda': 2.4756926328514327e-05, 'subsample': 0.9205368744704638, 'colsample_bytree': 0.9825559179901701, 'colsample_bylevel': 0.7031434579302598}. Best is trial 52 with value: 2189.4955436455225.
#
# --- Optimization Finished ---
# Best RMSE: 2189.4955
# Best Params: {'learning_rate': 0.01450028044288516, 'max_depth': 14, 'min_child_weight': 14, 'gamma': 1.9766679831681936e-07, 'reg_alpha': 0.0018198884824782875, 'reg_lambda': 7.217774845660382e-05, 'subsample': 0.9604144092351541, 'colsample_bytree': 0.9046189573755721, 'colsample_bylevel': 0.6107605025348347}

# %%
# Train the final model with best parameters
best_params = study.best_params
# Remember to add the non-tuned parameters back in
best_params.update({'tree_method': 'hist', 'device': 'cuda', 'n_estimators': 2000})

final_model = xgb.XGBRegressor(**best_params)
final_model.fit(X_train, y_train_log, eval_set=[(X_val, y_val_log)], verbose=100)

# Now run your original calculate_metrics function on this final_model
# Out:
# [0]	validation_0-rmse:1.10312
# [100]	validation_0-rmse:0.36465
# [200]	validation_0-rmse:0.21092
# [300]	validation_0-rmse:0.18754
# [400]	validation_0-rmse:0.18348
# [500]	validation_0-rmse:0.18263
# [600]	validation_0-rmse:0.18269
# [700]	validation_0-rmse:0.18299
# [800]	validation_0-rmse:0.18361
# [900]	validation_0-rmse:0.18421
# [1000]	validation_0-rmse:0.18485
# [1100]	validation_0-rmse:0.18554
# [1200]	validation_0-rmse:0.18611
# [1300]	validation_0-rmse:0.18670
# [1400]	validation_0-rmse:0.18733
# [1500]	validation_0-rmse:0.18780
# [1600]	validation_0-rmse:0.18836
# [1700]	validation_0-rmse:0.18886
# [1800]	validation_0-rmse:0.18937
# [1900]	validation_0-rmse:0.18986
# [1999]	validation_0-rmse:0.19033
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=0.6107605025348347, colsample_bynode=None,
#              colsample_bytree=0.9046189573755721, device='cuda',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=1.9766679831681936e-07, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01450028044288516, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=14, max_leaves=None,
#              min_child_weight=14, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
y_train_pred_log = final_model.predict(X_train)
y_val_pred_log = final_model.predict(X_val)
y_test_pred_log = final_model.predict(X_test)

# Convert back to original price scale
y_train_actual = np.expm1(y_train_log)
y_train_pred = np.expm1(y_train_pred_log)

y_val_actual = np.expm1(y_val_log)
y_val_pred = np.expm1(y_val_pred_log)

# %%
train_metrics = calculate_metrics(y_train_actual, y_train_pred, "Training")
val_metrics = calculate_metrics(y_val_actual, y_val_pred, "Validation")
# Out:
# Training Metrics:
#   RMSE: $1,788.74
#   MAE:  $518.19
#   R²:   0.9542
#   MAPE: 8.83%
#
# Validation Metrics:
#   RMSE: $2,223.92
#   MAE:  $640.14
#   R²:   0.9286
#   MAPE: 10.83%
